# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc

from sys import path
from os.path import abspath
path.append(abspath("/home/ng136/nico"))
import ng_functions as ng

from glob import glob
from pathlib import Path
import warnings
from time import time
from tqdm import tqdm

from datetime import datetime

# %% [markdown]
# # Load treated libraries

# %%
n_states = ['N1a', 'N1b', 'N2', 'N3', 'N4', 'N5', 'N6']

adata = sc.read('/n/groups/klein/nico/neutrophils/backups/totalseq_exp3_all_cells_acd40_annotated_embedding_33603x17824_backup_220325_12h01.h5ad')
#adata = adata[(adata.obs['smoothed_Zilionis'].isin(n_states))]

# %% [markdown]
# # Compute CLR expression

# %%
adtdata = sc.AnnData(adata.obs.loc[adata.obs['sample_condition'] != 'KP19_CD101',
                                   adata.obs.columns.str.contains('_Ab') & ~adata.obs.columns.isin(['CD101_Ab', 'Lair1_Ab', 'Rat_IgG2a_Ab'])])

adtdata.obs = adata.obs.loc[adata.obs['sample_condition'] != 'KP19_CD101',~adata.obs.columns.str.contains('_Ab')]
                            
adtdata.layers['clr'] = ng.clr_transform(adtdata.X)

# %%
adtdata.obs
# Out:
#                         orig.ident  nCount_RNA  nFeature_RNA repl  condition  \
# 1.KP19_CXCL10neg.21118           0      2451.0           822    1          4
# 1.KP19_CXCL10neg.21119           0      3353.0           892    1          4
# 1.KP19_CXCL10neg.21120           0      6571.0          1601    1          4
# 1.KP19_CXCL10neg.21121           0      3476.0           856    1          4
# 1.KP19_CXCL10neg.21122           0      8513.0          2817    1          4
# ...                            ...         ...           ...  ...        ...
# 2.KP19_CXCL10pos.38539           0     17647.0          3599    2          3
# 2.KP19_CXCL10pos.38540           0     22582.0          4096    2          3
# 2.KP19_CXCL10pos.38541           0      1973.0           797    2          3
# 2.KP19_CXCL10pos.38542           0     12007.0          3399    2          3
# 2.KP19_CXCL10pos.38543           0      4774.0          1191    2          3
#
#                                    barcode                  cellID  \
# 1.KP19_CXCL10neg.21118  AAACCCAAGAGAAGGT-1  1.KP19_CXCL10neg.21118
# 1.KP19_CXCL10neg.21119  AAACCCAAGAGTCACG-1  1.KP19_CXCL10neg.21119
# 1.KP19_CXCL10neg.21120  AAACCCAAGGGAGGCA-1  1.KP19_CXCL10neg.21120
# 1.KP19_CXCL10neg.21121  AAACCCAAGGGCAGAG-1  1.KP19_CXCL10neg.21121
# 1.KP19_CXCL10neg.21122  AAACCCAAGGGTACAC-1  1.KP19_CXCL10neg.21122
# ...                                    ...                     ...
# 2.KP19_CXCL10pos.38539  TTTGTTGCAGACAATA-1  2.KP19_CXCL10pos.38539
# 2.KP19_CXCL10pos.38540  TTTGTTGCATCTGCGG-1  2.KP19_CXCL10pos.38540
# 2.KP19_CXCL10pos.38541  TTTGTTGGTATTAAGG-1  2.KP19_CXCL10pos.38541
# 2.KP19_CXCL10pos.38542  TTTGTTGGTGGATCGA-1  2.KP19_CXCL10pos.38542
# 2.KP19_CXCL10pos.38543  TTTGTTGTCTTGATTC-1  2.KP19_CXCL10pos.38543
#
#                                 sampleID  nCount_ADT  nFeature_ADT  ...  \
# 1.KP19_CXCL10neg.21118  1.KP19_CXCL10neg       171.0            13  ...
# 1.KP19_CXCL10neg.21119  1.KP19_CXCL10neg       110.0            15  ...
# 1.KP19_CXCL10neg.21120  1.KP19_CXCL10neg       310.0            15  ...
# 1.KP19_CXCL10neg.21121  1.KP19_CXCL10neg       217.0            17  ...
# 1.KP19_CXCL10neg.21122  1.KP19_CXCL10neg       835.0            15  ...
# ...                                  ...         ...           ...  ...
# 2.KP19_CXCL10pos.38539  2.KP19_CXCL10pos       652.0            21  ...
# 2.KP19_CXCL10pos.38540  2.KP19_CXCL10pos      1829.0            19  ...
# 2.KP19_CXCL10pos.38541  2.KP19_CXCL10pos       388.0            16  ...
# 2.KP19_CXCL10pos.38542  2.KP19_CXCL10pos       490.0            19  ...
# 2.KP19_CXCL10pos.38543  2.KP19_CXCL10pos       174.0            14  ...
#
#                         nFeature_MUX  n_counts  n_genes  mito_fraction  \
# 1.KP19_CXCL10neg.21118             2    2451.0      822       0.003672
# 1.KP19_CXCL10neg.21119             2    3353.0      892       0.002088
# 1.KP19_CXCL10neg.21120             2    6571.0     1601       0.002891
# 1.KP19_CXCL10neg.21121             2    3476.0      856       0.001151
# 1.KP19_CXCL10neg.21122             2    8513.0     2817       0.038999
# ...                              ...       ...      ...            ...
# 2.KP19_CXCL10pos.38539             2   17647.0     3599       0.038930
# 2.KP19_CXCL10pos.38540             2   22582.0     4096       0.010584
# 2.KP19_CXCL10pos.38541             2    1973.0      797       0.009630
# 2.KP19_CXCL10pos.38542             1   12007.0     3399       0.038394
# 2.KP19_CXCL10pos.38543             2    4774.0     1191       0.002095
#
#                             library_name sample_condition      cell_barcode  \
# 1.KP19_CXCL10neg.21118  1.KP19_CXCL10neg   KP19_CXCL10neg  AAACCCAAGAGAAGGT
# 1.KP19_CXCL10neg.21119  1.KP19_CXCL10neg   KP19_CXCL10neg  AAACCCAAGAGTCACG
# 1.KP19_CXCL10neg.21120  1.KP19_CXCL10neg   KP19_CXCL10neg  AAACCCAAGGGAGGCA
# 1.KP19_CXCL10neg.21121  1.KP19_CXCL10neg   KP19_CXCL10neg  AAACCCAAGGGCAGAG
# 1.KP19_CXCL10neg.21122  1.KP19_CXCL10neg   KP19_CXCL10neg  AAACCCAAGGGTACAC
# ...                                  ...              ...               ...
# 2.KP19_CXCL10pos.38539  2.KP19_CXCL10pos   KP19_CXCL10pos  TTTGTTGCAGACAATA
# 2.KP19_CXCL10pos.38540  2.KP19_CXCL10pos   KP19_CXCL10pos  TTTGTTGCATCTGCGG
# 2.KP19_CXCL10pos.38541  2.KP19_CXCL10pos   KP19_CXCL10pos  TTTGTTGGTATTAAGG
# 2.KP19_CXCL10pos.38542  2.KP19_CXCL10pos   KP19_CXCL10pos  TTTGTTGGTGGATCGA
# 2.KP19_CXCL10pos.38543  2.KP19_CXCL10pos   KP19_CXCL10pos  TTTGTTGTCTTGATTC
#
#                        experiment most_likely_Zilionis smoothed_Zilionis
# 1.KP19_CXCL10neg.21118          3                  N1a               N1a
# 1.KP19_CXCL10neg.21119          3                  N1a               N1a
# 1.KP19_CXCL10neg.21120          3                  N1a               N1a
# 1.KP19_CXCL10neg.21121          3                  N1a               N1a
# 1.KP19_CXCL10neg.21122          3                 Mac4              Mac4
# ...                           ...                  ...               ...
# 2.KP19_CXCL10pos.38539          3               MonoDC            MonoDC
# 2.KP19_CXCL10pos.38540          3                 Mac2              Mac2
# 2.KP19_CXCL10pos.38541          3                  N1b               N1b
# 2.KP19_CXCL10pos.38542          3                 Mac4              Mac4
# 2.KP19_CXCL10pos.38543          3                  N1a               N1a
#
# [33603 rows x 21 columns]

# %% [markdown]
# # Inherit embedding from gene expression

# %%
adtdata.obsp = adata.obsp.copy()
adtdata.obsm = adata.obsm.copy()
adtdata.uns = adata.uns.copy()

# %% [markdown]
# # Save

# %%
start = time()
fname = '/n/groups/klein/nico/neutrophils/backups/totalseq_exp3_all_cells_treated_adt_clr_{}x{}_backup_{}.h5ad'.format(*adtdata.shape,ng.now())
adtdata.write(fname)
print(fname)
ng.print_etime(start)
# Out:
# /n/groups/klein/nico/neutrophils/backups/totalseq_exp3_all_cells_treated_adt_clr_33603x20_backup_221215_14h27.h5ad
# Elapsed time: 0 minutes and 0.3 seconds.
